# %%
import pandas as pd

# %%
PatientInfo = pd.read_csv("PatientInfo.csv")

# %%
PatientInfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4004 entries, 0 to 4003
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   patient_id          4004 non-null   int64
#  1   global_num          2806 non-null   float64
#  2   sex                 3674 non-null   object
#  3   birth_year          3267 non-null   object
#  4   age                 3525 non-null   object
#  5   country             4004 non-null   object
#  6   province            4004 non-null   object
#  7   city                3926 non-null   object
#  8   disease             18 non-null     object
#  9   infection_case      3211 non-null   object
#  10  infection_order     31 non-null     float64
#  11  infected_by         899 non-null    object
#  12  contact_number      680 non-null    object
#  13  symptom_onset_date  535 non-null    object
#  14  confirmed_date      4001 non-null   object
# ...

# %%
PatientInfo.head()
# Out:
#    patient_id  global_num     sex birth_year  age country province  \
# 0  1000000001         2.0    male       1964  50s   Korea    Seoul
# 1  1000000002         5.0    male       1987  30s   Korea    Seoul
# 2  1000000003         6.0    male       1964  50s   Korea    Seoul
# 3  1000000004         7.0    male       1991  20s   Korea    Seoul
# 4  1000000005         9.0  female       1992  20s   Korea    Seoul
#
#           city disease        infection_case  infection_order infected_by  \
# 0   Gangseo-gu     NaN       overseas inflow              1.0         NaN
# 1  Jungnang-gu     NaN       overseas inflow              1.0         NaN
# 2    Jongno-gu     NaN  contact with patient              2.0  2002000001
# 3      Mapo-gu     NaN       overseas inflow              1.0         NaN
# 4  Seongbuk-gu     NaN  contact with patient              2.0  1000000002
#
#   contact_number symptom_onset_date confirmed_date released_date  \
# ...

# %%
Weather = pd.read_csv("Weather.csv")

# %%
SearchTrend = pd.read_csv("SearchTrend.csv")

# %%
Weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25807 entries, 0 to 25806
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   code                   25807 non-null  int64
#  1   province               25807 non-null  object
#  2   date                   25807 non-null  object
#  3   avg_temp               25792 non-null  float64
#  4   min_temp               25802 non-null  float64
#  5   max_temp               25804 non-null  float64
#  6   precipitation          25807 non-null  float64
#  7   max_wind_speed         25798 non-null  float64
#  8   most_wind_direction    25778 non-null  float64
#  9   avg_relative_humidity  25787 non-null  float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 2.0+ MB

# %%
Weather['date'] = pd.to_datetime(Weather['date'], format= '%Y-%m-%d')

# %%
Weather_new = Weather[Weather['date'] >= '2020-01-23']

# %%
Weather_new.tail(5)
# Out:
#         code          province       date  avg_temp  min_temp  max_temp  \
# 25802  50000      Jeollabuk-do 2020-05-31      20.9      17.3      26.7
# 25803  51000      Jeollanam-do 2020-05-31      19.1      16.2      21.7
# 25804  60000  Gyeongsangbuk-do 2020-05-31      18.5      11.2      24.7
# 25805  61000  Gyeongsangnam-do 2020-05-31      19.3      14.6      24.6
# 25806  70000           Jeju-do 2020-05-31      19.7      17.1      23.6
#
#        precipitation  max_wind_speed  most_wind_direction  \
# 25802            0.0             4.2                250.0
# 25803            0.0             4.4                 50.0
# 25804            0.0             5.0                180.0
# 25805            0.0             4.0                140.0
# 25806            0.0             6.2                 70.0
#
#        avg_relative_humidity
# 25802                   61.8
# 25803                   84.1
# 25804                   77.4
# 25805                   71.5
# 25806                   88.1

# %%
SearchTrend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1613 entries, 0 to 1612
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         1613 non-null   object
#  1   cold         1613 non-null   float64
#  2   flu          1613 non-null   float64
#  3   pneumonia    1613 non-null   float64
#  4   coronavirus  1613 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 63.1+ KB

# %%
SearchTrend['date'] = pd.to_datetime(SearchTrend['date'], format= '%Y-%m-%d')

# %%
SearchTrend_new = SearchTrend[SearchTrend['date'] >= '2020-01-23']

# %%
SearchTrend_new.tail()
# Out:
#            date     cold      flu  pneumonia  coronavirus
# 1608 2020-05-27  0.11326  0.05254    0.13017      3.93397
# 1609 2020-05-28  0.12081  0.04581    0.13890      5.55656
# 1610 2020-05-29  0.16454  0.04599    0.11699      4.95803
# 1611 2020-05-30  0.12208  0.03299    0.09090      3.41698
# 1612 2020-05-31  0.11990  0.03499    0.08436      3.25944

# %%
PatientInfo.tail()
# Out:
#       patient_id  global_num     sex birth_year  age country province  \
# 3999  7000000010         NaN  female        NaN  20s   Korea  Jeju-do
# 4000  7000000011         NaN    male        NaN  30s   Korea  Jeju-do
# 4001  7000000012         NaN  female        NaN  20s   Korea  Jeju-do
# 4002  7000000013         NaN  female        NaN  10s   China  Jeju-do
# 4003  7000000014         NaN  female        NaN  30s   Korea  Jeju-do
#
#          city disease        infection_case  infection_order infected_by  \
# 3999  Jeju-do     NaN       overseas inflow              NaN         NaN
# 4000  Jeju-do     NaN  contact with patient              NaN  7000000009
# 4001  Jeju-do     NaN       overseas inflow              NaN         NaN
# 4002  Jeju-do     NaN       overseas inflow              NaN         NaN
# 4003  Jeju-do     NaN         Itaewon Clubs              NaN         NaN
#
#      contact_number symptom_onset_date confirmed_date released_date  \
# ...

# %%
PatientInfo['confirmed_date'] = pd.to_datetime(PatientInfo['confirmed_date'], format= '%Y-%m-%d')

# %%
dd = pd.merge(PatientInfo, Weather_new, left_on=["confirmed_date", "province"], right_on=["date", "province"])

# %%
dd.to_csv('dd.csv')

# %%
dd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3945 entries, 0 to 3944
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   patient_id             3945 non-null   int64
#  1   global_num             2804 non-null   float64
#  2   sex                    3615 non-null   object
#  3   birth_year             3255 non-null   object
#  4   age                    3474 non-null   object
#  5   country                3945 non-null   object
#  6   province               3945 non-null   object
#  7   city                   3867 non-null   object
#  8   disease                18 non-null     object
#  9   infection_case         3152 non-null   object
#  10  infection_order        31 non-null     float64
#  11  infected_by            887 non-null    object
#  12  contact_number         633 non-null    object
#  13  symptom_onset_date     504 non-null    object
# ...

# %%
PatientInfo['province'].drop_duplicates().count()
# Out:
# 17

# %%
Weather['province'].drop_duplicates().count()
# Out:
# 16

# %%
PatientInfo['province'].drop_duplicates()
# Out:
# 0                   Seoul
# 863                 Busan
# 1007                Daegu
# 1070              Gwangju
# 1100              Incheon
# 1332              Daejeon
# 1378                Ulsan
# 1430               Sejong
# 1477          Gyeonggi-do
# 2330           Gangwon-do
# 2385    Chungcheongbuk-do
# 2437    Chungcheongnam-do
# 2583         Jeollabuk-do
# 2604         Jeollanam-do
# 2623     Gyeongsangbuk-do
# 3868     Gyeongsangnam-do
# 3990              Jeju-do
# Name: province, dtype: object

# %%
Weather['province'].drop_duplicates()
# Out:
# 0                 Seoul
# 1                 Busan
# 2                 Daegu
# 3               Gwangju
# 4               Incheon
# 5               Daejeon
# 6                 Ulsan
# 7           Gyeonggi-do
# 8            Gangwon-do
# 9     Chungcheongbuk-do
# 10    Chungcheongnam-do
# 11         Jeollabuk-do
# 12         Jeollanam-do
# 13     Gyeongsangbuk-do
# 14     Gyeongsangnam-do
# 15              Jeju-do
# Name: province, dtype: object

# %%
df1 = pd.merge(PatientInfo, Weather_new, left_on=["confirmed_date", "province"], right_on=["date", "province"], how='left')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4004 entries, 0 to 4003
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   patient_id             4004 non-null   int64
#  1   global_num             2806 non-null   float64
#  2   sex                    3674 non-null   object
#  3   birth_year             3267 non-null   object
#  4   age                    3525 non-null   object
#  5   country                4004 non-null   object
#  6   province               4004 non-null   object
#  7   city                   3926 non-null   object
#  8   disease                18 non-null     object
#  9   infection_case         3211 non-null   object
#  10  infection_order        31 non-null     float64
#  11  infected_by            899 non-null    object
#  12  contact_number         680 non-null    object
#  13  symptom_onset_date     535 non-null    object
# ...

# %%
df2 = pd.merge(df1, SearchTrend_new, on='date', how='left' )

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4004 entries, 0 to 4003
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   patient_id             4004 non-null   int64
#  1   global_num             2806 non-null   float64
#  2   sex                    3674 non-null   object
#  3   birth_year             3267 non-null   object
#  4   age                    3525 non-null   object
#  5   country                4004 non-null   object
#  6   province               4004 non-null   object
#  7   city                   3926 non-null   object
#  8   disease                18 non-null     object
#  9   infection_case         3211 non-null   object
#  10  infection_order        31 non-null     float64
#  11  infected_by            899 non-null    object
#  12  contact_number         680 non-null    object
#  13  symptom_onset_date     535 non-null    object
# ...

# %%
df2.to_csv('df2.csv')

# %%
df2['first'] = df2.infected_by.isnull()

# %%
df2
# Out:
#       patient_id  global_num     sex birth_year  age country province  \
# 0     1000000001         2.0    male       1964  50s   Korea    Seoul
# 1     1000000002         5.0    male       1987  30s   Korea    Seoul
# 2     1000000003         6.0    male       1964  50s   Korea    Seoul
# 3     1000000004         7.0    male       1991  20s   Korea    Seoul
# 4     1000000005         9.0  female       1992  20s   Korea    Seoul
# ...          ...         ...     ...        ...  ...     ...      ...
# 3999  7000000010         NaN  female        NaN  20s   Korea  Jeju-do
# 4000  7000000011         NaN    male        NaN  30s   Korea  Jeju-do
# 4001  7000000012         NaN  female        NaN  20s   Korea  Jeju-do
# 4002  7000000013         NaN  female        NaN  10s   China  Jeju-do
# 4003  7000000014         NaN  female        NaN  30s   Korea  Jeju-do
#
#              city disease        infection_case  ...  max_temp precipitation  \
# ...

# %%
df2[df2['first'] == 1]
# Out:
#       patient_id  global_num     sex birth_year  age country province  \
# 0     1000000001         2.0    male       1964  50s   Korea    Seoul
# 1     1000000002         5.0    male       1987  30s   Korea    Seoul
# 3     1000000004         7.0    male       1991  20s   Korea    Seoul
# 7     1000000008        13.0    male       1992  20s   Korea    Seoul
# 8     1000000009        19.0    male       1983  30s   Korea    Seoul
# ...          ...         ...     ...        ...  ...     ...      ...
# 3998  7000000009      9651.0  female        NaN  20s   Korea  Jeju-do
# 3999  7000000010         NaN  female        NaN  20s   Korea  Jeju-do
# 4001  7000000012         NaN  female        NaN  20s   Korea  Jeju-do
# 4002  7000000013         NaN  female        NaN  10s   China  Jeju-do
# 4003  7000000014         NaN  female        NaN  30s   Korea  Jeju-do
#
#              city disease   infection_case  ...  max_temp precipitation  \
# ...

# %%
df2[df2['first'] == 0]
# Out:
#       patient_id  global_num     sex birth_year  age country  \
# 2     1000000003         6.0    male       1964  50s   Korea
# 4     1000000005         9.0  female       1992  20s   Korea
# 5     1000000006        10.0  female       1966  50s   Korea
# 6     1000000007        11.0    male       1995  20s   Korea
# 9     1000000010        21.0  female       1960  60s   Korea
# ...          ...         ...     ...        ...  ...     ...
# 3949  6100000082         NaN    male       1963  50s   Korea
# 3956  6100000089         NaN    male       1960  60s   Korea
# 3978  6100000111         NaN    male       1999  20s   Korea
# 3979  6100000112         NaN    male       1954  60s   Korea
# 4000  7000000011         NaN    male        NaN  30s   Korea
#
#               province          city disease        infection_case  ...  \
# 2                Seoul     Jongno-gu     NaN  contact with patient  ...
# 4                Seoul   Seongbuk-gu     NaN  contact with patient  ...
# ...

# %%
df2[df2['first'] == 0].groupby(['province'])['patient_id'].count()
# Out:
# province
# Busan                 33
# Chungcheongbuk-do      8
# Chungcheongnam-do    113
# Daegu                  6
# Daejeon               17
# Gwangju               12
# Gyeonggi-do          429
# Gyeongsangbuk-do      98
# Gyeongsangnam-do      32
# Incheon                2
# Jeju-do                1
# Jeollabuk-do           2
# Jeollanam-do           3
# Sejong                12
# Seoul                118
# Ulsan                 13
# Name: patient_id, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# 20s     860
# 50s     625
# 30s     493
# 40s     483
# 60s     423
# 70s     210
# 80s     162
# 10s     160
# 0s       60
# 90s      47
# 100s      1
# 30        1
# Name: age, dtype: int64

# %%
df2['age'].value_counts()
# Out:
# 20s     860
# 50s     625
# 30s     493
# 40s     483
# 60s     423
# 70s     210
# 80s     162
# 10s     160
# 0s       60
# 90s      47
# 100s      1
# 30        1
# Name: age, dtype: int64

# %%
ad = pd.DataFrame(df2['age'].value_counts())

# %%
sns.barplot(x=ad.index, y=ad['age'])

# %%
df2.groupby(['province'])['patient_id'].count()
# Out:
# province
# Busan                 144
# Chungcheongbuk-do      52
# Chungcheongnam-do     146
# Daegu                  63
# Daejeon                46
# Gangwon-do             55
# Gwangju                30
# Gyeonggi-do           853
# Gyeongsangbuk-do     1245
# Gyeongsangnam-do      122
# Incheon               232
# Jeju-do                14
# Jeollabuk-do           21
# Jeollanam-do           19
# Sejong                 47
# Seoul                 863
# Ulsan                  52
# Name: patient_id, dtype: int64
